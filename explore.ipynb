# %%
import pandas as pd
import nflreadpy as nfl
import polars as pl

# %%
# get all teams

# %%
pbp = nfl.load_pbp()

# %%
type(pbp)
# Out:
# polars.dataframe.frame.DataFrame

# %%
bills_bengals = pbp.filter(
    (pl.col("home_team") == "BUF") & (pl.col("away_team") == "CIN")
)

# %%
bills_bengals.head(1)
# Out:
# shape: (1, 372)
# ┌─────────┬───────────────┬─────────────┬───────────┬───┬──────────────┬─────────┬───────┬─────────┐
# │ play_id ┆ game_id       ┆ old_game_id ┆ home_team ┆ … ┆ xyac_success ┆ xyac_fd ┆ xpass ┆ pass_oe │
# │ ---     ┆ ---           ┆ ---         ┆ ---       ┆   ┆ ---          ┆ ---     ┆ ---   ┆ ---     │
# │ f64     ┆ str           ┆ str         ┆ str       ┆   ┆ f64          ┆ f64     ┆ f64   ┆ f64     │
# ╞═════════╪═══════════════╪═════════════╪═══════════╪═══╪══════════════╪═════════╪═══════╪═════════╡
# │ 1.0     ┆ 2025_14_CIN_B ┆ 2025120710  ┆ BUF       ┆ … ┆ null         ┆ null    ┆ null  ┆ null    │
# │         ┆ UF            ┆             ┆           ┆   ┆              ┆         ┆       ┆         │
# └─────────┴───────────────┴─────────────┴───────────┴───┴──────────────┴─────────┴───────┴─────────┘

# %%
teams = nfl.load_teams()

print(teams.shape)
print(teams.columns)
teams.head()
# Out:
# (36, 16)
# ['team_abbr', 'team_name', 'team_id', 'team_nick', 'team_conf', 'team_division', 'team_color', 'team_color2', 'team_color3', 'team_color4', 'team_logo_wikipedia', 'team_logo_espn', 'team_wordmark', 'team_conference_logo', 'team_league_logo', 'team_logo_squared']
# shape: (5, 16)
# ┌───────────┬────────────┬─────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ team_abbr ┆ team_name  ┆ team_id ┆ team_nick ┆ … ┆ team_word ┆ team_conf ┆ team_leag ┆ team_logo │
# │ ---       ┆ ---        ┆ ---     ┆ ---       ┆   ┆ mark      ┆ erence_lo ┆ ue_logo   ┆ _squared  │
# │ str       ┆ str        ┆ i32     ┆ str       ┆   ┆ ---       ┆ go        ┆ ---       ┆ ---       │
# │           ┆            ┆         ┆           ┆   ┆ str       ┆ ---       ┆ str       ┆ str       │
# │           ┆            ┆         ┆           ┆   ┆           ┆ str       ┆           ┆           │
# ...
